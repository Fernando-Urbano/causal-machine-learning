# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split

# Define nonlinear functions for mu0(x) and p(x)
def mu0_function(X, s):
    if s == 0:
        return np.zeros(X.shape[0])
    return np.sum(np.sin(X[:, :s]), axis=1)

def g_function(X, s):
    if s == 0:
        return np.zeros(X.shape[0])
    g = np.zeros(X.shape[0])
    if s >= 1:
        g += 0.5 * np.sin(X[:, 0])
    if s >= 2:
        g += (X[:, 1] ** 2) / 4
    if s >= 3:
        g -= np.cos(X[:, 2])
    for j in range(3, s):
        g += 0.3 * (X[:, j] ** 3)
    return g

# Generate synthetic data
def generate_data(n, d, s, tau=1, seed=None):
    if seed is not None:
        np.random.seed(seed)
    X = np.random.normal(0, 1, (n, d))
    mu0_vals = mu0_function(X, s)
    g_vals = g_function(X, s)
    p_x = 1 / (1 + np.exp(-g_vals))
    T = np.random.binomial(1, p_x)
    Y = T * (mu0_vals + tau) + (1 - T) * mu0_vals + np.random.normal(0, 1, n)
    return X, Y, T, p_x, mu0_vals

# Define PyTorch models
class MLPRegressor(nn.Module):
    def __init__(self, input_dim):
        super(MLPRegressor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.model(x)

class MLPClassifier(nn.Module):
    def __init__(self, input_dim):
        super(MLPClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Train a PyTorch model
def train_pytorch_model(model, X, y, epochs=10, batch_size=32):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    criterion = nn.MSELoss() if isinstance(model, MLPRegressor) else nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
    y_tensor = torch.tensor(y, dtype=torch.float32).to(device)

    dataset = torch.utils.data.TensorDataset(X_tensor, y_tensor)
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

    model.train()
    for epoch in range(epochs):
        for batch_X, batch_y in loader:
            optimizer.zero_grad()
            outputs = model(batch_X).squeeze()
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

    model.eval()
    return model

# Fit propensity score and mu0 using PyTorch models
def fit_p_deepnet(X, T, epochs=10, batch_size=32):
    model = MLPClassifier(X.shape[1])
    trained_model = train_pytorch_model(model, X, T, epochs, batch_size)
    return lambda newX: trained_model(torch.tensor(newX, dtype=torch.float32)).detach().numpy().squeeze()

def fit_mu0_deepnet(X, Y, T, epochs=10, batch_size=32):
    X0 = X[T == 0]
    Y0 = Y[T == 0]
    model = MLPRegressor(X.shape[1])
    trained_model = train_pytorch_model(model, X0, Y0, epochs, batch_size)
    return lambda newX: trained_model(torch.tensor(newX, dtype=torch.float32)).detach().numpy().squeeze()

# Plugin estimator
def compute_plugin_estimator(Y, T, p_hat_func, X):
    p_hat_vals = p_hat_func(X)
    p_hat_vals = np.clip(p_hat_vals, 1e-3, 1 - 1e-3)
    p_bar = np.mean(p_hat_vals)
    mu1_hat = np.mean((T * Y) / p_bar)
    mu0_hat = np.mean(((1 - T) * p_hat_vals * Y) / (1 - p_hat_vals))
    return mu1_hat - mu0_hat

# DR estimator
def compute_DR_estimator(Y, T, p_hat_func, mu0_hat_func, X):
    p_hat_vals = p_hat_func(X)
    p_hat_vals = np.clip(p_hat_vals, 1e-3, 1 - 1e-3)
    p_bar = np.mean(p_hat_vals)
    mu0_hat_vals = mu0_hat_func(X)
    mu1_hat = np.mean((T * Y) / p_bar)
    term = T * mu0_hat_vals + ((1 - T) * p_hat_vals * Y) / (1 - p_hat_vals)
    mu0_hat = np.mean(term) / p_bar
    return mu1_hat - mu0_hat

# Simulation setup
def run_simulation(ns, ds, sparsities, methods, reps=50, tau=1, seed=123):
    np.random.seed(seed)
    results = []

    for n in ns:
        for d in ds:
            for s in [sp for sp in sparsities if sp <= d]:
                for method in methods:
                    tau_pi_vals = []
                    tau_dr_vals = []

                    for _ in range(reps):
                        X, Y, T, _, _ = generate_data(n, d, s, tau)
                        if method == "rf":
                            p_model = RandomForestClassifier().fit(X, T)
                            p_hat_func = lambda newX: p_model.predict_proba(newX)[:, 1]
                            mu0_model = RandomForestRegressor().fit(X[T == 0], Y[T == 0])
                            mu0_hat_func = lambda newX: mu0_model.predict(newX)
                        elif method == "deepnet":
                            p_hat_func = fit_p_deepnet(X, T)
                            mu0_hat_func = fit_mu0_deepnet(X, Y, T)

                        tau_pi_vals.append(compute_plugin_estimator(Y, T, p_hat_func, X))
                        tau_dr_vals.append(compute_DR_estimator(Y, T, p_hat_func, mu0_hat_func, X))

                    new_result = {
                        'n': n,
                        'd': d,
                        's': s,
                        'method': method,
                        'plugin_mean': np.mean(tau_pi_vals),
                        'plugin_sd': np.std(tau_pi_vals),
                        'dr_mean': np.mean(tau_dr_vals),
                        'dr_sd': np.std(tau_dr_vals)
                    }
                    print(new_result)

                    results.append(new_result)

    return results

seed_opt = np.random.randint(0, 1000)

results = run_simulation(
    ns=[1000, 5000, 15000],
    ds=[1, 3, 5, 10],
    sparsities=[1, 3, 5, 10],
    methods=["rf", "deepnet"],
    reps=1,
    tau=1,
    seed=seed_opt
)

results_df = pd.DataFrame(results)
timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")
results_df.to_csv(f"q2b-data/q2b_all_simulation_results_{timestamp}_{seed_opt:.0f}.csv", index=False)
# Out:
# {'n': 1000, 'd': 1, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.0972459317294079), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0550662060269063), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 1, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(0.9488018513597329), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.6822590396880113), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 3, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.0515766044417905), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.785805626220468), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 3, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.077838848831024), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8429487125914686), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 3, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(0.9914212148964818), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9764278464011225), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 3, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.0735759952119548), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0763596169508929), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 5, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.1078532541417232), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8486600364699664), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 5, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.1301506540913862), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9859784652758619), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 5, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.1081595468929593), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9261866260037129), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 5, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.0036539882366868), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0196516115267893), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 5, 's': 5, 'method': 'rf', 'plugin_mean': np.float64(1.3987183684530433), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.1044925907753262), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 5, 's': 5, 'method': 'deepnet', 'plugin_mean': np.float64(1.2825547694938098), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.6927355313448481), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.017737624957058), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8385326920126507), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0267990247946805), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8080309249207319), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.0835953783073673), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0167420776556966), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.0347966862574234), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9045647964024688), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 5, 'method': 'rf', 'plugin_mean': np.float64(1.3040163952290094), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9326127156469997), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 5, 'method': 'deepnet', 'plugin_mean': np.float64(1.2095015577701145), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.7319503447086412), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 10, 'method': 'rf', 'plugin_mean': np.float64(1.6897772643743134), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.6650270297406942), 'dr_sd': np.float64(0.0)}
# {'n': 1000, 'd': 10, 's': 10, 'method': 'deepnet', 'plugin_mean': np.float64(1.5348765778138982), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(-0.303568677666163), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 1, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.0809768636548582), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9418764457690262), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 1, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0653736474318716), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.7459190704944454), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 3, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.1232176740912512), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9555883800938871), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 3, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0518693596962356), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9920212953987066), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 3, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.073510648588277), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9779173776671081), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 3, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(0.974528175550131), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8252221082882852), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 5, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.1562518981010117), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0340080462159722), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 5, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0014999891711338), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8652521042927771), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 5, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.1154533018096837), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9910715006173838), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 5, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.0670768773751056), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.954324286347765), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 5, 's': 5, 'method': 'rf', 'plugin_mean': np.float64(1.3791751408840212), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0437921704031539), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 5, 's': 5, 'method': 'deepnet', 'plugin_mean': np.float64(1.2310328811669946), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.43977328969601936), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.0991671075604357), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.980718749587381), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0116742489252128), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9660300103810742), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.0792070807168657), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9583306322002344), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.0151696043498977), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8067178776126125), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 5, 'method': 'rf', 'plugin_mean': np.float64(1.3313309137586375), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0549237218999263), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 5, 'method': 'deepnet', 'plugin_mean': np.float64(1.1755059973882047), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.5463758119137871), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 10, 'method': 'rf', 'plugin_mean': np.float64(1.81942537834132), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.5623482108290019), 'dr_sd': np.float64(0.0)}
# {'n': 5000, 'd': 10, 's': 10, 'method': 'deepnet', 'plugin_mean': np.float64(1.3768796814721627), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(-0.5517235868148964), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 1, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.105056307437955), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9966702261865382), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 1, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0748271921711146), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8972341246112444), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 3, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.096221138054777), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.99600547954003), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 3, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.168439538005232), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9340178520557091), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 3, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.130987004877888), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0102878747578143), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 3, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.054992637965241), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8910697512015828), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 5, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.0685693479222433), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9652821158865417), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 5, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.0502227153506323), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.946419098640962), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 5, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.0620240232060185), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9651045974492823), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 5, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.108512742361882), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8714054010410803), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 5, 's': 5, 'method': 'rf', 'plugin_mean': np.float64(1.389189757302561), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9954667032984126), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 5, 's': 5, 'method': 'deepnet', 'plugin_mean': np.float64(1.215036764714264), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.532008178241242), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 1, 'method': 'rf', 'plugin_mean': np.float64(1.1266407441711979), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.0154733687724378), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 1, 'method': 'deepnet', 'plugin_mean': np.float64(1.1219607359730681), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.1183531934238216), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 3, 'method': 'rf', 'plugin_mean': np.float64(1.0843305343817373), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9530056311146451), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 3, 'method': 'deepnet', 'plugin_mean': np.float64(1.0501531328930114), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.8302611769280013), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 5, 'method': 'rf', 'plugin_mean': np.float64(1.3792342584210984), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.9959189145665792), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 5, 'method': 'deepnet', 'plugin_mean': np.float64(1.1490309991592484), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(0.45807893509566444), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 10, 'method': 'rf', 'plugin_mean': np.float64(1.7640521307153232), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(1.4160882177336935), 'dr_sd': np.float64(0.0)}
# {'n': 15000, 'd': 10, 's': 10, 'method': 'deepnet', 'plugin_mean': np.float64(1.295011071573923), 'plugin_sd': np.float64(0.0), 'dr_mean': np.float64(-0.4298576826337246), 'dr_sd': np.float64(0.0)}
#         n   d   s   method  plugin_mean  plugin_sd   dr_mean  dr_sd
# 0    1000   1   1       rf     1.097246        0.0  1.055066    0.0
# 1    1000   1   1  deepnet     0.948802        0.0  0.682259    0.0
# 2    1000   3   1       rf     1.051577        0.0  0.785806    0.0
# 3    1000   3   1  deepnet     1.077839        0.0  0.842949    0.0
# 4    1000   3   3       rf     0.991421        0.0  0.976428    0.0
# 5    1000   3   3  deepnet     1.073576        0.0  1.076360    0.0
# 6    1000   5   1       rf     1.107853        0.0  0.848660    0.0
# 7    1000   5   1  deepnet     1.130151        0.0  0.985978    0.0
# 8    1000   5   3       rf     1.108160        0.0  0.926187    0.0
# 9    1000   5   3  deepnet     1.003654        0.0  1.019652    0.0
# 10   1000   5   5       rf     1.398718        0.0  1.104493    0.0
# 11   1000   5   5  deepnet     1.282555        0.0  0.692736    0.0
